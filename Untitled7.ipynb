# %% [markdown]
# <a href="https://colab.research.google.com/github/deeptanghosh02/GEOG5990M_Deeptanshu-Ghosh/blob/main/Untitled7.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # *Getting Spatial Boundaries*

# %%
import os
import geopandas as gpd

# Get the absolute path to the current directory
current_dir = os.getcwd()
print(f"Current working directory: {current_dir}")

# Construct the absolute path to the data file
data_file_path = os.path.join(current_dir, "data", "lsoa_boundaries.geojson")

# Verify if the file exists
if os.path.exists(data_file_path):
    print(f"File found at: {data_file_path}")
    lsoa = gpd.read_file(data_file_path)
    print(lsoa.head())
else:
    print(f"Error: File not found at: {data_file_path}")
    print("Please check the file path and name, and make sure the file exists.")
# Out:
# Current working directory: /content
# File found at: /content/data/lsoa_boundaries.geojson
#     LSOA21CD                   LSOA21NM   LEP22CD1  \
# 0  E01000001        City of London 001A  E37000051
# 1  E01000002        City of London 001B  E37000051
# 2  E01000003        City of London 001C  E37000051
# 3  E01000005        City of London 001E  E37000051
# 4  E01000006  Barking and Dagenham 016A  E37000051
#
#                                  LEP22NM1 LEP22CD2 LEP22NM2  ObjectId geometry
# 0  The London Economic Action Partnership     None     None         1     None
# 1  The London Economic Action Partnership     None     None         2     None
# 2  The London Economic Action Partnership     None     None         3     None
# 3  The London Economic Action Partnership     None     None         4     None
# 4  The London Economic Action Partnership     None     None         5     None

# %% [markdown]
# ## *Data* *Cleaning*

# %%
import os
import geopandas as gpd

# Get the absolute path to the current directory
current_dir = os.getcwd()
print(f"Current working directory: {current_dir}")

# Construct the absolute path to the data file
# Added a check for the existence of the "data" directory.
data_dir = os.path.join(current_dir, "data")
if not os.path.exists(data_dir):
    os.makedirs(data_dir) # Create the directory if it doesn't exist.
    print(f"Created directory: {data_dir}")

data_file_path = os.path.join(data_dir, "lsoa_boundaries.geojson")


# Verify if the file exists
if os.path.exists(data_file_path):
    print(f"File found at: {data_file_path}")
    lsoa = gpd.read_file(data_file_path)
    print(lsoa.head())
else:
    print(f"Error: File not found at: {data_file_path}")
    print("Please check the file path and name, and make sure the file exists.")
    print("You may need to upload the 'lsoa_boundaries.geojson' file to the 'data' directory in your Colab environment.")
# Out:
# Current working directory: /content
# File found at: /content/data/lsoa_boundaries.geojson
#     LSOA21CD                   LSOA21NM   LEP22CD1  \
# 0  E01000001        City of London 001A  E37000051
# 1  E01000002        City of London 001B  E37000051
# 2  E01000003        City of London 001C  E37000051
# 3  E01000005        City of London 001E  E37000051
# 4  E01000006  Barking and Dagenham 016A  E37000051
#
#                                  LEP22NM1 LEP22CD2 LEP22NM2  ObjectId geometry
# 0  The London Economic Action Partnership     None     None         1     None
# 1  The London Economic Action Partnership     None     None         2     None
# 2  The London Economic Action Partnership     None     None         3     None
# 3  The London Economic Action Partnership     None     None         4     None
# 4  The London Economic Action Partnership     None     None         5     None

# %%
# Statistical Modeling: IMD and Obesity Association
import pandas as pd
import numpy as np
import statsmodels.api as sm
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats


# 1. Prepare the data (assuming merged DataFrame exists from previous steps)
# Changed 'lsoa_boundaries7CD' to 'OtherColumn' as it's the likely intended column
model_data = merged[['OtherColumn', 'IMD Score', 'Value']].dropna()
model_data = model_data.rename(columns={'Value': 'Obesity_Pct'})

# Add quadratic term for potential non-linear relationship
model_data['IMD_Score_Squared'] = model_data['IMD Score']**2



# 2. Exploratory Analysis
print("\n=== Descriptive Statistics ===")
print(model_data[['IMD Score', 'Obesity_Pct']].describe())

print("\n=== Correlation ===")
corr, p_value = stats.pearsonr(model_data['IMD Score'], model_data['Obesity_Pct'])
print(f"Pearson r: {corr:.3f}, p-value: {p_value:.4f}")

# Scatterplot with regression line
plt.figure(figsize=(10,6))
sns.regplot(x='IMD Score', y='Obesity_Pct', data=model_data,
            scatter_kws={'alpha':0.3}, line_kws={'color':'red'})
plt.title("Deprivation vs Obesity Prevalence (n={})".format(len(model_data)))
plt.xlabel("Index of Multiple Deprivation Score")
plt.ylabel("Obesity Prevalence (%)")
plt.show()

# 3. Linear Regression Model
X = sm.add_constant(model_data['IMD Score'])  # Add intercept
y = model_data['Obesity_Pct']

model = sm.OLS(y, X).fit()
print("\n=== Simple Linear Regression ===")
print(model.summary())

# 4. Polynomial Regression (testing non-linearity)
X_poly = sm.add_constant(pd.DataFrame({
    'IMD_Score': model_data['IMD Score'],
    'IMD_Score_Squared': model_data['IMD_Score_Squared']
}))

poly_model = sm.OLS(y, X_poly).fit()
print("\n=== Polynomial Regression ===")
print(poly_model.summary())

# 5. Model Comparison
print("\n=== Model Comparison ===")
print(f"Linear Model AIC: {model.aic:.2f}")
print(f"Polynomial Model AIC: {poly_model.aic:.2f}")

# 6. Diagnostic Plots
fig, axes = plt.subplots(1, 2, figsize=(12,5))

# Residuals plot
axes[0].scatter(model.fittedvalues, model.resid, alpha=0.5)
axes[0].axhline(y=0, color='r', linestyle='--')
axes[0].set_xlabel("Fitted values")
axes[0].set_ylabel("Residuals")
axes[0].set_title("Residuals vs Fitted")

# Q-Q plot
sm.qqplot(model.resid, line='s', ax=axes[1])
axes[1].set_title("Q-Q Plot")

plt.tight_layout()
plt.show()
# Out:
# === Descriptive Statistics ===
#        IMD Score  Obesity_Pct
# count   5.000000     5.000000
# mean    3.000000    30.000000
# std     1.581139    15.811388
# min     1.000000    10.000000
# 25%     2.000000    20.000000
# 50%     3.000000    30.000000
# 75%     4.000000    40.000000
# max     5.000000    50.000000
#
# === Correlation ===
# Pearson r: 1.000, p-value: 0.0000
# === Simple Linear Regression ===
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            Obesity_Pct   R-squared:                       1.000
# Model:                            OLS   Adj. R-squared:                  1.000
# Method:                 Least Squares   F-statistic:                 4.851e+30
# Date:                Wed, 07 May 2025   Prob (F-statistic):           2.06e-46
# Time:                        17:49:47   Log-Likelihood:                 153.55
# No. Observations:                   5   AIC:                            -303.1
# Df Residuals:                       3   BIC:                            -303.9
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const      -1.688e-14   1.51e-14     -1.121      0.344   -6.48e-14     3.1e-14
# IMD Score     10.0000   4.54e-15    2.2e+15      0.000      10.000      10.000
# ==============================================================================
# Omnibus:                          nan   Durbin-Watson:                   0.041
# Prob(Omnibus):                    nan   Jarque-Bera (JB):                0.638
# Skew:                           0.000   Prob(JB):                        0.727
# Kurtosis:                       1.250   Cond. No.                         8.37
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
# === Polynomial Regression ===
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            Obesity_Pct   R-squared:                       1.000
# Model:                            OLS   Adj. R-squared:                  1.000
# Method:                 Least Squares   F-statistic:                 1.488e+30
# Date:                Wed, 07 May 2025   Prob (F-statistic):           6.72e-31
# Time:                        17:49:47   Log-Likelihood:                 153.35
# No. Observations:                   5   AIC:                            -300.7
# Df Residuals:                       2   BIC:                            -301.9
# Df Model:                           2
# Covariance Type:            nonrobust
# =====================================================================================
#                         coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------
# const             -1.132e-14   3.93e-14     -0.288      0.800    -1.8e-13    1.58e-13
# IMD_Score            10.0000      3e-14   3.34e+14      0.000      10.000      10.000
# IMD_Score_Squared  1.055e-15    4.9e-15      0.215      0.850      -2e-14    2.21e-14
# ==============================================================================
# Omnibus:                          nan   Durbin-Watson:                   0.343
# Prob(Omnibus):                    nan   Jarque-Bera (JB):                1.373
# Skew:                          -1.283   Prob(JB):                        0.503
# Kurtosis:                       2.941   Cond. No.                         85.9
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
# === Model Comparison ===
# Linear Model AIC: -303.11
# Polynomial Model AIC: -300.69
# /usr/local/lib/python3.11/dist-packages/statsmodels/stats/stattools.py:74: ValueWarning: omni_normtest is not valid with less than 8 observations; 5 samples were given.
#   warn("omni_normtest is not valid with less than 8 observations; %i "
# /usr/local/lib/python3.11/dist-packages/statsmodels/stats/stattools.py:74: ValueWarning: omni_normtest is not valid with less than 8 observations; 5 samples were given.
#   warn("omni_normtest is not valid with less than 8 observations; %i "

# %% [markdown]
# ## ***Non-Spatial Plot***

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

# Assuming your data is in two separate DataFrames: 'df1' and 'df2'
# Replace these with the actual names of your DataFrames

# Example:
df1 = pd.DataFrame({'IMD Score': [1, 2, 3, 4, 5], 'OtherColumn': ['a', 'b', 'c', 'd', 'e']}) # Define df1
df2 = pd.DataFrame({'Value': [10, 20, 30, 40, 50], 'OtherColumn': ['a', 'b', 'c', 'd', 'e']}) # Define df2

# Merge the DataFrames based on a common column (e.g., 'OtherColumn')
merged = pd.merge(df1, df2, on='OtherColumn')

# Now you can create the plot
# Change the sample size to be less than or equal to the number of rows in merged
sns.lmplot(x='IMD Score', y='Value', data=merged.sample(min(1000, len(merged))))
plt.title("Deprivation vs Obesity Prevalence")
plt.xlabel("IMD Score (higher = more deprived)")
plt.ylabel("Obesity Prevalence %")
plt.show() # Add this line to display the plot

# %% [markdown]
# # *Spatial Plot*

# %%
# Simplified Spatial Visualization
import geopandas as gpd
import matplotlib.pyplot as plt

# 1. Load your data (assuming you have a GeoDataFrame)
# If not, create one from your merged data:
# Assuming 'lsoa' is your GeoDataFrame with geometry data
# and 'merged' contains your IMD Score and Value
# Assuming 'LSOA21CD' is the column to merge on in 'lsoa'
gdf = lsoa.merge(merged, left_on='LSOA21CD', right_on='OtherColumn', how='left') # Merge data with lsoa GeoDataFrame

# Now gdf has both geometry and your data
# 2. Basic choropleth map
fig, ax = plt.subplots(1, figsize=(12, 8))

# Plot deprivation scores
# Changed column to 'IMD Score' as 'imd_2019.csv' is likely not a column name
# Added 'try-except' block to handle potential ValueError and set aspect to 'auto'
try:
    gdf.plot(column='IMD Score',
             ax=ax,
             legend=True,
             legend_kwds={'label': "Deprivation Score (higher = more deprived)",
                         'orientation': "horizontal",
                         'shrink': 0.5},
             cmap='viridis',
             edgecolor='lightgrey',  # Light boundary lines
             linewidth=0.3)
except ValueError:
    print("ValueError encountered, setting aspect to 'auto'")
    ax.set_aspect('auto')  # Set aspect to 'auto' as a fallback

# Customize
ax.set_title("Neighborhood Deprivation Levels", fontsize=16)
ax.set_axis_off()  # Remove axes

# Add scale bar (optional)
from mpl_toolkits.axes_grid1 import make_axes_locatable
divider = make_axes_locatable(ax)
cax = divider.append_axes("bottom", size="5%", pad=0.1)
plt.colorbar(ax.collections[0], cax=cax, orientation='horizontal')

plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-d7ea5375d483> in <cell line: 0>()
#       8 # and 'merged' contains your IMD Score and Value
#       9 # Assuming 'LSOA21CD' is the column to merge on in 'lsoa'
# ---> 10 gdf = lsoa.merge(merged, left_on='LSOA21CD', right_on='OtherColumn', how='left') # Merge data with lsoa GeoDataFrame
#      11
#      12 # Now gdf has both geometry and your data
#
# NameError: name 'lsoa' is not defined
